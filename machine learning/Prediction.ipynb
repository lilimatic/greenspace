# %%
import os

# %%
directory = f'/Users/lilimatic/greenspace'
os.chdir(directory)

# %%
from functions.data import df

# %%
df
# Out:
#       Age   Gender  \
# 0    15-24    Male
# 1    25-40    Male
# 2    41-64  Female
# 3    15-24  Female
# 4    41-64  Female
# ..     ...     ...
# 409  41-64  Female
# 410  15-24  Female
# 411  15-24  Female
# 412  15-24  Female
# 413  15-24    Male
#
#     Municipality in which you visit parks or squares: (circle all that apply)  \
# 0    Vračar, Novi Beograd, Palilula, Savski Venac, ...
# 1                         Vračar, Palilula, Stari grad
# 2       Vračar, Palilula, Stari gradmore than 5 people
# 3       Vračar, Palilula, Stari grad, Zvezdara, Grocka
# 4                                     Vračar, Palilula
# ..                                                 ...
# 409                                         Stari grad
# 410                                             Vračar
# 411                                             Vračar
# 412                                             Vračar
# 413                                             Vračar
#
# ...
