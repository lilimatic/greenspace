# %%
import os

# %%
directory = f'/Users/lilimatic/greenspace'
os.chdir(directory)

# %%
from functions.data import df
from functions.function import contingencytab

# %%
book='crosstab/crosstab_app_safety'

# %%
#Questions of interest

#App and safety

app_related = ['Would you be interested in technology that would allow you to know how many people are in a specific place you would like to go?'
               #,'If your identity was not revealed, would you want to provide your phone’s location (see question 10)?'
              ]

safety = ['While using parks or squares, do you behave according to social distancing regulations standing a minimum of 2.0 meters apart from other people?'
    ,'Would you feelsafe regarding the corona virus if there was monitoring of park or square usage that you could access through your phone?'
               ,'Would you feel physically safe if there was monitoring of park or square usage that you could access through your phone?'  ]

# %%
for x in app_related:
    for y in safety:
        a,b = contingencytab(x,y,book)
        display(a,b)
# Out:
# Would you be interested in technology that would allow you to know how many people are in a specific place you would like to go? VS While using parks or squares, do you behave according to social distancing regulations standing a minimum of 2.0 meters apart from other people?
# /Users/lilimatic/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py:643: UserWarning: merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#   warnings.warn(msg, UserWarning)
#                                                      No  Yes  All  \
# Would you be interested in technology that woul...
# No                                                   44   99  143
# Yes                                                  59  198  257
# All                                                 103  297  400
#
#                                                     (While using parks or squares, do you behave according to social distancing regulations standing a minimum of 2.0 meters apart from other people?, No)  \
# Would you be interested in technology that woul...
# No                                                                                              11.00
# Yes                                                                                             14.75
# All                                                                                             25.75
#
#                                                     (While using parks or squares, do you behave according to social distancing regulations standing a minimum of 2.0 meters apart from other people?, Yes)  \
# Would you be interested in technology that woul...
# No                                                                                              24.75
# Yes                                                                                             49.50
# All                                                                                             74.25
#
#                                                     (While using parks or squares, do you behave according to social distancing regulations standing a minimum of 2.0 meters apart from other people?, All)
# Would you be interested in technology that woul...
# No                                                                                              35.75
# Yes                                                                                             64.25
# All                                                                                            100.00
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    2.9327
# 1                    p-value =    0.0868
# 2               Cramer's phi =    0.0856
# Would you be interested in technology that would allow you to know how many people are in a specific place you would like to go? VS Would you feelsafe regarding the corona virus if there was monitoring of park or square usage that you could access through your phone?
# /Users/lilimatic/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py:643: UserWarning: merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#   warnings.warn(msg, UserWarning)
#                                                      No  Yes  All  \
# Would you be interested in technology that woul...
# No                                                  117   26  143
# Yes                                                  58  199  257
# All                                                 175  225  400
#
#                                                     (Would you feelsafe regarding the corona virus if there was monitoring of park or square usage that you could access through your phone?, No)  \
# Would you be interested in technology that woul...
# No                                                                                              29.25
# Yes                                                                                             14.50
# All                                                                                             43.75
#
#                                                     (Would you feelsafe regarding the corona virus if there was monitoring of park or square usage that you could access through your phone?, Yes)  \
# Would you be interested in technology that woul...
# No                                                                                               6.50
# Yes                                                                                             49.75
# All                                                                                             56.25
#
#                                                     (Would you feelsafe regarding the corona virus if there was monitoring of park or square usage that you could access through your phone?, All)
# Would you be interested in technology that woul...
# No                                                                                              35.75
# Yes                                                                                             64.25
# All                                                                                            100.00
#                 Chi-square test   results
# 0  Pearson Chi-square ( 1.0) =   131.0650
# 1                    p-value =     0.0000
# 2               Cramer's phi =     0.5724
# Would you be interested in technology that would allow you to know how many people are in a specific place you would like to go? VS Would you feel physically safe if there was monitoring of park or square usage that you could access through your phone?
# /Users/lilimatic/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py:643: UserWarning: merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#   warnings.warn(msg, UserWarning)
#                                                      No  Yes  All  \
# Would you be interested in technology that woul...
# No                                                  107   36  143
# Yes                                                  76  181  257
# All                                                 183  217  400
#
#                                                     (Would you feel physically safe if there was monitoring of park or square usage that you could access through your phone?, No)  \
# Would you be interested in technology that woul...
# No                                                                                              26.75
# Yes                                                                                             19.00
# All                                                                                             45.75
#
#                                                     (Would you feel physically safe if there was monitoring of park or square usage that you could access through your phone?, Yes)  \
# Would you be interested in technology that woul...
# No                                                                                               9.00
# Yes                                                                                             45.25
# All                                                                                             54.25
#
#                                                     (Would you feel physically safe if there was monitoring of park or square usage that you could access through your phone?, All)
# Would you be interested in technology that woul...
# No                                                                                              35.75
# Yes                                                                                             64.25
# All                                                                                            100.00
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =   75.8083
# 1                    p-value =    0.0000
# 2               Cramer's phi =    0.4353
