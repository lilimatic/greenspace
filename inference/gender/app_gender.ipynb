# %%
import os

# %%
directory = f'/Users/lilimatic/greenspace'
os.chdir(directory)

# %%
from functions.data import df
from functions.function import contingencytab

# %%
book ='crosstab/crosstab_gender/crosstab_app_gender'

# %%
#Questions of interest

#App and gender

gender = ['Gender']

app_related = ['Would you be interested in technology that would allow you to know how many people are in a specific place you would like to go?',
              'If your identity was not revealed, would you want to provide your phone’s location (see question 10)?']

# %%
for x in gender:
    for y in app_related:
        a,b = contingencytab(x,y,book)
        display(a,b)
# Out:
# Gender VS Would you be interested in technology that would allow you to know how many people are in a specific place you would like to go?
# /Users/lilimatic/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py:643: UserWarning: merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#   warnings.warn(msg, UserWarning)
#          No  Yes  All  \
# Gender
# Female   94  176  270
# Male     49   81  130
# All     143  257  400
#
#         (Would you be interested in technology that would allow you to know how many people are in a specific place you would like to go?, No)  \
# Gender
# Female                                              23.50
# Male                                                12.25
# All                                                 35.75
#
#         (Would you be interested in technology that would allow you to know how many people are in a specific place you would like to go?, Yes)  \
# Gender
# Female                                              44.00
# Male                                                20.25
# All                                                 64.25
#
#         (Would you be interested in technology that would allow you to know how many people are in a specific place you would like to go?, All)
# Gender
# Female                                               67.5
# Male                                                 32.5
# All                                                 100.0
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.3163
# 1                    p-value =    0.5738
# 2               Cramer's phi =    0.0281
# Gender VS If your identity was not revealed, would you want to provide your phone’s location (see question 10)?
# /Users/lilimatic/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py:643: UserWarning: merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#   warnings.warn(msg, UserWarning)
#         No, not at all  Yes, at all time  Yes, while using the app  All  \
# Gender
# Female             120                63                        87  270
# Male                52                32                        46  130
# All                172                95                       133  400
#
#         (If your identity was not revealed, would you want to provide your phone’s location (see question 10)?, No, not at all)  \
# Gender
# Female                                               30.0
# Male                                                 13.0
# All                                                  43.0
#
#         (If your identity was not revealed, would you want to provide your phone’s location (see question 10)?, Yes, at all time)  \
# Gender
# Female                                              15.75
# Male                                                 8.00
# All                                                 23.75
#
#         (If your identity was not revealed, would you want to provide your phone’s location (see question 10)?, Yes, while using the app)  \
# Gender
# Female                                              21.75
# Male                                                11.50
# All                                                 33.25
#
#         (If your identity was not revealed, would you want to provide your phone’s location (see question 10)?, All)
# Gender
# Female                                               67.5
# Male                                                 32.5
# All                                                 100.0
#                 Chi-square test  results
# 0  Pearson Chi-square ( 2.0) =    0.7278
# 1                    p-value =    0.6950
# 2                 Cramer's V =    0.0427
