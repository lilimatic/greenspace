# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
directory = f'/Users/lilimatic/greenspace'
os.chdir(directory)

# %%
from functions.function import table_creator
from functions.data import df

# %%
book = 'interest'

# %%
interest = ['Would you feel physically safe if there was monitoring of park or square usage that you could access through your phone?',
            'Would you be interested in technology that would allow you to know how many people are in a specific place you would like to go?',
            'If your identity was not revealed, would you want to provide your phone’s location (see question 10)?',
           'Would you feelsafe regarding the corona virus if there was monitoring of park or square usage that you could access through your phone?'
           ,'While using parks or squares, do you behave according to social distancing regulations standing a minimum of 2.0 meters apart from other people?']

# %%
for i in interest:
    print('\033[95m' + '\033[1m' + i+ '\033[0m')
    table_creator(df,i,book)
    display(table_creator(df,i,book))
# Out:
# Would you feel physically safe if there was monitoring of park or square usage that you could access through your phone?
#      count     %
# Yes    220  53.8
# No     189  46.2
# Would you be interested in technology that would allow you to know how many people are in a specific place you would like to go?
#      count     %
# Yes    261  63.8
# No     148  36.2
# If your identity was not revealed, would you want to provide your phone’s location (see question 10)?
#                           count     %
# No, not at all              177  43.3
# Yes, while using the app    136  33.3
# Yes, at all time             96  23.5
# Would you feelsafe regarding the corona virus if there was monitoring of park or square usage that you could access through your phone?
#      count     %
# Yes    228  55.7
# No     181  44.3
# While using parks or squares, do you behave according to social distancing regulations standing a minimum of 2.0 meters apart from other people?
#      count     %
# Yes    304  74.5
# No     104  25.5

# %%
for x in interest:
    #absolute
    print('\033[95m' + '\033[1m' + x+ '\033[0m')
    #print(df[x].value_counts(ascending=True))
    #relative
    #print('\033[95m' + '\033[1m' + x+ '\033[0m')
    #print(df[x].value_counts(ascending=True,normalize=True).mul(100).round(3))
    fig = plt.figure()
    ax = df[x].value_counts(ascending=True,normalize=True).mul(100).round(2).plot(kind='bar',title=x,color='r',figsize=(14,7)) #
    #np.round(df[x].value_counts(ascending=True,normalize=True)*100,2).to_csv('descriptive/activity/'+x+'_relative.csv')
    #df[x].value_counts(ascending=True).to_csv('descriptive/activity/'+x+'_absolute.csv')
    ax.set_xlabel(x)
    ax.set_ylabel('Frequency in percentage (%)')
    ax.set_xticks(list(range(len(df[x].unique())-1)))
    ax.set_xticklabels(['('+str(x+1)+')' for x in list(range(len(df[x].unique())-1))])
    plt.xticks(rotation=0)
    plt.show()
    fig.savefig('images/interest/' + x+'.png')
# Out:
# Would you feel physically safe if there was monitoring of park or square usage that you could access through your phone?
# Would you be interested in technology that would allow you to know how many people are in a specific place you would like to go?
# If your identity was not revealed, would you want to provide your phone’s location (see question 10)?
# Would you feelsafe regarding the corona virus if there was monitoring of park or square usage that you could access through your phone?
# While using parks or squares, do you behave according to social distancing regulations standing a minimum of 2.0 meters apart from other people?
